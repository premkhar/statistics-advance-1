# %% [markdown]
# 1  What is a random variable in probability theory
#
# : In probability theory, a random variable is a function that maps the outcomes of a random experiment to real numbers, allowing us to quantify and analyze the outcomes using probability distributions.
#
#
# 2 What are the types of random variables1
#
# : There are two main types of random variables: discrete and continuous.
# Discrete Random Variables:
# These can only take on a finite or countably infinite number of values, often whole numbers or integers (e.g., the number of heads in a coin toss, the number of cars passing a point in an hour).
# Continuous Random Variables:
# These can take on any value within a given range, including decimal values (e.g., height, weight, temperature, time).
#
#
# 3 What is the difference between discrete and continuous distributions
#
# : The key difference between discrete and continuous distributions lies in the nature of the values they can take: discrete distributions deal with countable, distinct values (like whole numbers), while continuous distributions encompass any value within a range.
#
# 4  What are probability distribution functions (PDF)
# : In the context of AI and statistics, a probability distribution function (PDF) describes the likelihood of different outcomes or values of a random variable, providing a framework for understanding how probabilities are distributed over a range of possible values.
# Here's a more detailed explanation:
#
#
# 5  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)1
#
# :The probability distribution function (PDF) describes the likelihood of a random variable taking a specific value, while the cumulative distribution function (CDF) describes the probability of a random variable being less than or equal to a certain value.
#
#  6 What is a discrete uniform distribution
#
#  : A uniform distribution is also known as a rectangular distribution.
#
#  7 What are the key properties of a Bernoulli distribution
#
#  :The key properties of a Bernoulli distribution are that it's a discrete probability distribution modeling a single trial with only two possible outcomes (success or failure), each with a fixed probability of occurrence, and the trials are independent.
#
#  8 What is the binomial distribution, and how is it used in probability
#
#  : The binomial distribution is a discrete probability distribution that models the probability of a certain number of successes in a fixed number of independent trials, each with the same probability of success. It's used in probability to analyze scenarios with two possible outcomes, like coin flips or quality control tests.
#
#  9 What is the Poisson distribution and where is it applied
#
#
#  : The Poisson distribution is a discrete probability distribution that models the probability of a certain number of events occurring within a fixed interval of time or space, given the average rate of those events. It's applied in scenarios where events occur randomly and independently at a constant rate, such as modeling customer arrivals, call center calls, or radioactive decay.
#
#  10 What is a continuous uniform distribution
#
#  :The uniform distribution (continuous) is one of the simplest probability distributions in statistics. It is a continuous distribution, this means that it takes values within a specified range, e.g. between 0 and 1.
#
#  11 What are the characteristics of a normal distribution
#
#  : A normal distribution, also known as a Gaussian distribution or bell curve, is characterized by its symmetrical, bell-shaped curve, where the mean, median, and mode are all equal, and the distribution is defined by its mean and standard deviation.
#
# 12   What is the standard normal distribution, and why is it important
#
# : The standard normal distribution is a specific type of normal distribution with a mean of 0 and a standard deviation of 1, often represented by the letter 'Z'. It's important because it simplifies probability calculations and comparisons across datasets, serving as a foundation for statistical analysis.
#
#  13 what is the Central Limit Theorem (CLT), and why is it critical in statistics1.
#  : Central Limit Theorem (CLT): Definition and Key CharacteristicsThe Central Limit Theorem (CLT) states that the distribution of sample means will approximate a normal distribution as the sample size increases, regardless of the original population distribution. This is critically important in statistics because it allows for the application of normal distribution methods to a wide range of statistical analyses, even when the underlying population isn't normally distributed.
#
#  14 How does the Central Limit Theorem relate to the normal distribution
#
#  : Yes, the Central Limit Theorem (CLT) is fundamentally related to the normal distribution, stating that the distribution of sample means will approach a normal distribution as the sample size increases, regardless of the original population's distribution.
#
#   15  What is the application of Z statistics in hypothesis testing
#
#   : In hypothesis testing, shared statistics, like sample means or standard deviations, are used to calculate test statistics and p-values, which help determine whether to reject or fail to reject the null hypothesis, providing evidence for or against a claim about a population.
#
#   16 How do you calculate a Z-score, and what does it represent
#
#   : A Z-score, calculated as (x - μ) / σ, measures how many standard deviations a data point (x) is away from the mean (μ) of a distribution, with σ being the standard deviation.
#
#   17 What are point estimates and interval estimates in statistics
#
#   :
#   : In statistics, a point estimate is a single value used to estimate an unknown population parameter, while an interval estimate provides a range of values that is likely to contain the true paramete
#
#   18 What is the significance of confidence intervals in statistical analysis
#
#   : Confidence intervals in statistical analysis are crucial because they provide a range of plausible values for an unknown population parameter, offering a more informative and nuanced understanding of the data than a single point estimate alone, and help quantify the uncertainty inherent in statistical inference.
#
#    19 What is the relationship between a Z-score and a confidence interval
#
#    : The z-score is directly related to the confidence interval, as it determines the margin of error and the width of the interval, representing the range within which the population parameter is likely to fall with a certain level of confidence.
#
#    20  How are Z-scores used to compare different distributions
#
#    : Z-scores, also known as standard scores, allow you to compare data points from different distributions by standardizing them, expressing each data point as a number of standard deviations away from the mean.
#
#    .21  What are the assumptions for applying the Central Limit Theorem
#
#    : To apply the Central Limit Theorem (CLT), you need randomly sampled, independent observations, a sufficiently large sample size, and a population with finite variance.
#
#    22  What is the concept of expected value in a probability distribution
#    : In probability distributions, the expected value, also known as the mean or mathematical expectation, is a weighted average of all possible outcomes, where each outcome is weighted by its probability.
#
#    .23 How does a probability distribution relate to the expected outcome of a random variable
#
#    : A probability distribution related to the expected outcome of a random variable describes the likelihood of each possible outcome, providing a way to model the expected value and understand the distribution of potential results.
